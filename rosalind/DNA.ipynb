# %%
s = "ACGACGTT"

# %%
count_A = s.count("A")
count_G = s.count("G")
count_C = s.count("C")
count_T = s.count("T")

# %%
print(count_A, count_C, count_G, count_T)
# Out:
# 230 223 245 243

# %%
s = "..."

# %%
count_A = s.count("A")
count_C = s.count("C")
count_G = s.count("G")
count_T = s.count("T")

# %%
print(count_A, count_C, count_G, count_T)
# Out:
# 197 221 233 226
