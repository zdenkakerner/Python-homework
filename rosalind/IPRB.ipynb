# %% [markdown]
# Random variable and probability(IPRB)
# N = k + m + n individuals
# k = AA
# m = Aa
# n = aa
# two random individual, what is the probability of dominant fenotype?

# %%
k = 19
m = 28
n = 17
N = k + m + n

# %%
result = (k/N) + (m/(N*(N-1))) * ((4*k+3*m+2*n-3)/4) + n/(N*(N-1))*(2*k+m)/2
print(result)
# Out:
# 0.767609126984127
