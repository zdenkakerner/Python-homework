# %%
s = "..."
s_reverse = s[::-1]
print(s_reverse)
# Out:
# ...

# %%
for letter in s_reverse:
    if letter == "T":
        s_T = s_reverse.replace("T", "a") 
print(s_T)
# Out:
# ...

# %%
for letter in s_T:
     if letter == "G":
       s_G = s_T.replace("G", "c")
print(s_G)
# Out:
# ...

# %%
for letter in s_G:
     if letter == "C":
       s_C = s_G.replace("C", "g")
print(s_C)
# Out:
# ...

# %%
for letter in s_G:
     if letter == "A":
       s_A = s_C.replace("A", "t")
print(s_A)
# Out:
# ...

# %%
result = s_A.upper()
print(result)
# Out:
# ...
