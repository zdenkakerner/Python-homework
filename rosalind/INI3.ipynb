# %%
string = "dKmVBmUWftzmtvykrkKJNzndYm8V3IKmkk3gg5SIKxZ92ko2ux0pKQGEkGhInfl6q4LYt3p3wO7GuznMfRPCtenotusC9rkDDetSLfFSCVhWNvyMV7sMyLBv4l5osyRzcristatellalSIm2jvj8JFRwK51W3agKwshwW7DkpvYQICAR."
#83 90 128 138

# %%
print(string[83:91])
# Out:
# BEf0fhZO

# %%
print(string[128:139])
# Out:
# d3xIcVtbVvg

# %%
x = "Ctenotu"
y = "cristatell"
print(x ,y)   #too slow :-(
# Out:
# Ctenotu cristatell

# %%
#new attempt
string = "PzkFAzli4hvGVcjPltHMegaloperdixFAqsccinereuscahF2XOEmbHHiw0LV4jNfvqi0xyOvpNzaIjT0JEBEf0fhZO2GSWVhAt87X2aIDYF4guGObqlrJenn8vnXOhNd3xIcVtbVvgkhDdQJS0G9jjVC5VzIGYIp0WPcmMQqFm."
# numbers 19 30 36 43
x = (string[19:31])
y = (string[36:44])
print(x ,y) #something wrong
# Out:
# Megaloperdix cinereus

# %%
string = "r27yHr5woSKHckr4SW612wzo5EPafx0WrILyEjAw7Buteo3jeIQoh1sejUHabxwv8m2q0KNO8E8j9t1AM30y92Nn4FtDzeLzERjTEnsCXdefh4zrfdXk2yGiY1cTDxVkV7GVKepofcsre7FePYgS9kunicusr20fEFNFLfcP."
# numbers 41 45 150 155
x = (string[41:46])
y = (string[150:156]) #has to be one more since second value should be included
print(x ,y)
# Out:
# Buteo unicus
