# %%
s1 = "..."
s2 = "..."

# %%
def hamm(s1, s2):
    distance = 0
    assert len(s1) == len(s2)
    for i in range(len(s1)):
        if s1[i] != s2[i]:
            distance += 1
    return distance

# %%
hamm(s1,s2)
# Out:
# 448
