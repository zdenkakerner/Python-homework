# %%
x = 5
x += 3
print(x)
# Out:
# 8

# %%
print(10 * 5)
# Out:
# 50

# %%
atom_name = "sodium"
print(atom_name[0:3])
# Out:
# sod

# %%
print(len("helium"))
# Out:
# 6

# %%
# x.strip() for no spaces
# replace("something", "with something")
