# %%
print(type(3.4))
# Out:
# <class 'float'>

# %%
print(type(3.25+4))
# Out:
# <class 'float'>

# %%
(31//3) + 1
# Out:
# 11

# %%
int(float("3.4"))
# Out:
# 3

# %%
print(max(1, 2, 3))
print(min('a', 'A', '0'))
# Out:
# 3
# 0

# %%
round(3.712)
# Out:
# 4
