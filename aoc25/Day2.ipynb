# %%
def invalid_IDs(s):
    first_half = s[0:int(len(s)/2)]
    second_half = s[int(len(s)/2):]
    
    if len(s) % 2 == 1:
        return False
    if first_half == second_half:
        return True
    else:
        return False

# %%
#s = "56"

# %%
#invalid_IDs()

# %%
#r = "11-22,95-115,998-1012,1188511880-1188511890,222220-222224,1698522-1698528,446443-446449,38593856-38593862,565653-565659,824824821-824824827,2121212118-2121212124"
r = "11-22"

# %%
tmp = r.split("-") #split ranges separated by comma into separated ranges

# %%
start = int(tmp[0])
stop = int(tmp[1])

# %%
r #now is r list of ranges separated by comma
# Out:
# '11-22'

# %%
for i in range(start, stop):
# Out:
# i
# i
# i
# i
# i
# i
# i
# i
# i
# i
# i
