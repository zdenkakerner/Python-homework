# %%
test = 6 + 2j

# %%
test
# Out:
# (6+2j)

# %%
test.imag, test.real
# Out:
# (2.0, 6.0)

# %%
1 + 2j + 3 + 5j
# Out:
# (4+7j)

# %%
(1 + 2j) * (1j)
# Out:
# (-2+1j)

# %%
s = "the quick brown fox jumps over the lazy dog"

# %%
s.split()
# Out:
# ['the', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']

# %%
type(s.split)
# Out:
# builtin_function_or_method

# %%
shopping = ["bread", "potatoes", "eggs", "flour", "rubber duck", "pizza", "milk"]

# %%
shopping
# Out:
# ['bread', 'potatoes', 'eggs', 'flour', 'rubber duck', 'pizza', 'milk']

# %%
shopping.sort()

# %%
shopping
# Out:
# ['bread', 'eggs', 'flour', 'milk', 'pizza', 'potatoes', 'rubber duck']

# %%
shopping.append("cheese")

# %%
shopping
# Out:
# ['bread',
#  'eggs',
#  'flour',
#  'milk',
#  'pizza',
#  'potatoes',
#  'rubber duck',
#  'cheese']

# %%
shopping.insert(0, "cheese")

# %%
shopping
# Out:
# ['cheese',
#  'bread',
#  'eggs',
#  'flour',
#  'milk',
#  'pizza',
#  'potatoes',
#  'rubber duck',
#  'cheese']

# %%
shopping.pop() #takes the last argument and shows it
# Out:
# 'cheese'

# %%
shopping
# Out:
# ['cheese',
#  'bread',
#  'eggs',
#  'flour',
#  'milk',
#  'pizza',
#  'potatoes',
#  'rubber duck']

# %%
words = s.split()

# %%
words
# Out:
# ['the', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']

# %%
words[-1] #last word
# Out:
# 'dog'

# %%
task = (words[3])

# %%
task
# Out:
# 'fox'

# %%
task[1]
# Out:
# 'o'

# %%
words[3] [1] #better
# Out:
# 'o'
