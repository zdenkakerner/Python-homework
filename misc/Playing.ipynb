# %% [markdown]
# # Experimenting with Python
# \<explanation here\>

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
10/3
# Out:
# 3.3333333333333335

# %%
10%3 #modulo
# Out:
# 1

# %%
10 // 3 #integrer division
# Out:
# 3

# %%
2**64 #the limit (4300 digits) for integer string conversion
# Out:
# 18446744073709551616

# %%
"hello" + "world"
# Out:
# 'helloworld'

# %%
"Hello " * 8
# Out:
# 'Hello Hello Hello Hello Hello Hello Hello Hello '

# %%
8 * "Hello "
# Out:
# 'Hello Hello Hello Hello Hello Hello Hello Hello '

# %% [markdown]
# #what hat does?

# %%
x = (3)
print(x)
# Out:
# 3

# %%
y = (10/7)
print(y)
# Out:
# 1.4285714285714286

# %%
print (x, y)
# Out:
# 3 1.4285714285714286

# %%
x = x + y

# %%
x
# Out:
# 4.428571428571429

# %%
s = "the quick brown fox jumps over the lazy dog"

# %%
s
# Out:
# 'the quick brown fox jumps over the lazy dog'

# %%
s.upper()
# Out:
# 'THE QUICK BROWN FOX JUMPS OVER THE LAZY DOG'

# %%
s.title()
# Out:
# 'The Quick Brown Fox Jumps Over The Lazy Dog'

# %%
s = s.capitalize()

# %%
s
# Out:
# 'The quick brown fox jumps over the lazy dog'

# %%
s = s.lower()

# %%
s.lower().count("the")
# Out:
# 2

# %%
help(s.lower)
# Out:
# Help on built-in function lower:
#
# lower() method of builtins.str instance
#     Return a copy of the string converted to lowercase.

# %%
s.split() #different strings separately - list, split at space
s.split("o") # delim "o" ##  /t (tab)
# Out:
# ['The quick br', 'wn f', 'x jumps ', 'ver the lazy d', 'g']
