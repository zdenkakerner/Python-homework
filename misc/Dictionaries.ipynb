# %%
shopping_list = {"bread" : 2,
    
} #mutable

# %%
len(shopping_list)
# Out:
# 1

# %%
grades = {'Juan': {'Maths': 2},
          'John': {'History': 1, 'Biology': 3},
          'Gianni': {'Biology': 1}}

grades['Juan']['History'] = 2
grades['Juan']['Biology'] = 1

grades['John']['Maths'] = 1

grades['Gianni']['History'] = 4
grades['Gianni']['Maths'] = 3

print(grades)
# Out:
# {'Juan': {'Maths': 2, 'History': 2, 'Biology': 1}, 'John': {'History': 1, 'Biology': 3, 'Maths': 1}, 'Gianni': {'Biology': 1, 'History': 4, 'Maths': 3}}

# %%
for number in [123, 52, 38, 48, 564]:
    double = number *2
    print(number, double)
# Out:
# 123 246
# 52 104
# 38 76
# 48 96
# 564 1128

# %%
s = "the quick brown fox jumps over the lazy dog"

# %%
for character in s:
    print(character)
# Out:
# t
# h
# e
#
# q
# u
# i
# c
# k
#
# b
# r
# o
# w
# n
#
# f
# o
# x
#
# j
# u
# m
# p
# s
#
# o
# v
# e
# r
#
# t
# h
# e
#
# l
# a
# z
# y
#
# d
# o
# g

# %%
for i in range(150):
    print("Help")
# Out:
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# Help
# ...

# %%
#for i in range (len(shopping)):
    #print ("Buy", shopping[i], times[i], " times in ", marker[i])

# %%
#for i, item in enumerate(shopping):
    #print(i, item)

# %%
total = 0
for char in "tin":
    total = total + 1

# %%
original = "tin"
result = ""
for char in original:
    result = char + result
print(result)
# Out:
# nit

# %%
total = 0
for word in ["red", "green", "blue"]:
    total = total + len(word)
print(total)
# Out:
# 12

# %%
lengths = []
for word in ["red", "green", "blue"]:
    lengths.append(len(word))
print(lengths)
# Out:
# [3, 5, 4]

# %%
words = ["red", "green", "blue"]
result = ""
for word in words:
    result = result + word
print(result)
# Out:
# redgreenblue

# %%
first_letters = ""
for word in ["red", "green", "blue"]:
     first_letters = first_letters + word[0].upper()
print(first_letters)
# Out:
# RGB

# %%
data = [1,2,2,5]
total = 0
cumulative = []
for number in data:
    total = total + number
    cumulative.append(total)
print(cumulative)
# Out:
# [1, 3, 5, 10]

# %%
message = ""
for number in range(10):
    # use a if the number is a multiple of 3, otherwise use b
    if (number % 3) == 0:
        message = message + "a"
    else:
        message = message + "b"
print(message)
# Out:
# abbabbabba

# %%
seasons = ['Spring', 'Summer', 'Fall', 'Winter']
print('My favorite season is ', seasons[3])
# Out:
# My favorite season is  Winter
