# %%
fruit = "banana"
if fruit == "banana":
    print("this is banana")
else:
    print("this is not a banana")
# Out:
# this is banana

# %%
fruits = ["apple", "banana", "grapes", "oranges", "pomelo", "ananas", "kiwi", "banana"]
for i in range(len(fruits)):
    print(fruits[i])
    if fruits[i] == "banana":
        print("found banana at position", i)
# Out:
# apple
# banana
# found banana at position 1
# grapes
# oranges
# pomelo
# ananas
# kiwi
# banana
# found banana at position 7

# %% [markdown]
# # Exercises

# %%
original = [-1.5, 0.2, 0.4, 0.0, -1.3, 0.4]
result = []
for value in original:
    if value < 0:
        result.append(0)
    else:
        result.append(1)
print(result)
# Out:
# [0, 1, 1, 1, 0, 1]

# %%
values = [8, 25, -13, -24]
smallest, largest = None, None
for v in values:
    if smallest is None and largest is None:
        smallest, largest = v, v
    else:
        smallest = min(smallest, v)
        largest = max(largest, v)
print(smallest, largest)
# Out:
# -24 25
