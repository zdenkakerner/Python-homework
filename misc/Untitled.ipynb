# %%
b = 4.5
print(type(b))
# Out:
# <class 'float'>

# %%
s = ("Today is nice weather")
type(s)
# Out:
# str

# %%
print(type(5-3))
# Out:
# <class 'int'>

# %%
print(type("hello"*6))
# Out:
# <class 'str'>

# %%
some_long_string = "the quick brown fox jumps over the lazy dog"
len(some_long_string)
# Out:
# 43

# %%
len(str(1992)) #how to count digits
# Out:
# 4

# %%
some_number = "76" # makes integer
1 + int(some_number)
# Out:
# 77

# %%
test = "test test test test"
test.replace("e", "a")
# Out:
# 'tast tast tast tast'
